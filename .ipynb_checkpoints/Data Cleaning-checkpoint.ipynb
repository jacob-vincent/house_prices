# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import xgboost as xgb
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## Load data

# %%
train_df=pd.read_csv('train.csv')

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# Turn MSSubClass levels into dummy variables
dummy_df=pd.get_dummies(train_df['MSSubClass'])
train_df = train_df.join(dummy_df)
train_df=train_df.drop('MSSubClass',axis=1)

# %%
dummy_df=pd.get_dummies(train_df['MSZoning'])
train_df = train_df.join(dummy_df)
train_df=train_df.drop('MSZoning',axis=1)

# %%
dummy_df=pd.get_dummies(train_df['Street'])
train_df = train_df.join(dummy_df)
train_df=train_df.drop('Street',axis=1)

# %%
train_df['Alley'].value_counts()
# Out:
# Grvl    50
# Pave    40
# Name: Alley, dtype: int64

# %%
dummy_df = pd.get_dummies(train_df['Alley'],dummy_na=True)
dummy_df.head()
# Out:
#    Grvl  Pave  NaN
# 0     0     0    1
# 1     0     0    1
# 2     0     0    1
# 3     0     0    1
# 4     0     0    1

# %%
train_df = train_df.merge(dummy_df, how = 'left')
train_df = train_df.drop('Alley',axis=1)

# %%
train_df.head()
# Out:
#    Id  LotFrontage  LotArea LotShape LandContour Utilities LotConfig  \
# 0   1         65.0     8450      Reg         Lvl    AllPub    Inside
# 1   1         65.0     8450      Reg         Lvl    AllPub    Inside
# 2   1         65.0     8450      Reg         Lvl    AllPub    Inside
# 3   1         65.0     8450      Reg         Lvl    AllPub    Inside
# 4   1         65.0     8450      Reg         Lvl    AllPub    Inside
#
#   LandSlope Neighborhood Condition1 ... 180 190 C (all)  FV  RH  RL  RM Grvl  \
# 0       Gtl      CollgCr       Norm ...   0   0       0   0   0   1   0    0
# 1       Gtl      CollgCr       Norm ...   0   0       0   0   0   1   0    0
# 2       Gtl      CollgCr       Norm ...   0   0       0   0   0   1   0    0
# 3       Gtl      CollgCr       Norm ...   0   0       0   0   0   1   0    0
# 4       Gtl      CollgCr       Norm ...   0   0       0   0   0   1   0    0
#
#   Pave NaN
# 0    1   0
# 1    1   0
# 2    1   0
# 3    1   0
# 4    1   0
#
# [5 rows x 100 columns]
